# %% [markdown]
# # Exploratory Data Analysis (EDA) for AgriSentry
#
# This notebook contains standard EDA steps before feeding the dataset into the YOLO object detection model. We will inspect sample images, calculate class distributions, and analyze bounding box sizes.

# %%
import os
import matplotlib.pyplot as plt
import cv2

print("Ready for EDA on pest images!")
